# %% [markdown]
# > import the dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#load the dataset to a pandas dataframe
creditcard_data=pd.read_csv('/content/creditcard.csv')

# %%
creditcard_data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0     0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1     0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2     1 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3     1 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4     2 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
creditcard_data.tail()
# Out:
#          Time        V1         V2  ...       V28   Amount  Class
# 110999  72054 -6.874321 -14.465573  ...  0.740556  4229.51    0.0
# 111000  72055 -0.448999   1.111371  ...  0.127756     1.29    0.0
# 111001  72055  1.279970  -0.266108  ...  0.004009     6.99    0.0
# 111002  72056  1.158484  -0.276407  ...  0.012670    28.75    0.0
# 111003  72056 -3.250378   0.921773  ...       NaN      NaN    NaN
#
# [5 rows x 31 columns]

# %%
creditcard_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111004 entries, 0 to 111003
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    111004 non-null  int64
#  1   V1      111004 non-null  float64
#  2   V2      111004 non-null  float64
#  3   V3      111004 non-null  float64
#  4   V4      111004 non-null  float64
#  5   V5      111004 non-null  float64
#  6   V6      111004 non-null  float64
#  7   V7      111004 non-null  float64
#  8   V8      111004 non-null  float64
#  9   V9      111004 non-null  float64
#  10  V10     111004 non-null  float64
#  11  V11     111004 non-null  float64
#  12  V12     111004 non-null  float64
#  13  V13     111004 non-null  float64
#  14  V14     111004 non-null  float64
#  15  V15     111004 non-null  float64
#  16  V16     111004 non-null  float64
#  17  V17     111004 non-null  float64
#  18  V18     111004 non-null  float64
#  19  V19     111004 non-null  float64
#  20  V20     111004 non-null  float64
#  21  V21     111004 non-null  float64
#  22  V22     111004 non-null  float64
#  23  V23     111003 non-null  float64
#  24  V24     111003 non-null  float64
#  25  V25     111003 non-null  float64
#  26  V26     111003 non-null  float64
#  27  V27     111003 non-null  float64
#  28  V28     111003 non-null  float64
#  29  Amount  111003 non-null  float64
#  30  Class   111003 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 26.3 MB

# %%
creditcard_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
creditcard_data['Class'].value_counts()
# Out:
# Class
# 0.0    110764
# 1.0       239
# Name: count, dtype: int64

# %%
legit = creditcard_data[creditcard_data['Class'] == 0]
fraud = creditcard_data[creditcard_data['Class'] == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (110764, 31)
# (239, 31)

# %%
legit.Amount.describe()
# Out:
# count    110764.000000
# mean         95.779389
# std         259.830589
# min           0.000000
# 25%           7.000000
# 50%          25.000000
# 75%          86.190000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     239.000000
# mean      119.677573
# std       255.678875
# min         0.000000
# 25%         1.000000
# 50%         7.610000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
creditcard_data.groupby('Class').mean()
# Out:
#                Time        V1        V2  ...       V27       V28      Amount
# Class                                    ...
# 0.0    45139.748221 -0.244418 -0.031206  ...  0.000357  0.001865   95.779389
# 1.0    38848.740586 -5.982672  4.179679  ...  0.533488  0.067655  119.677573
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#          Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 107187  70322 -0.830736 -0.099328  1.856743  ...  0.018876  0.124941  106.04    0.0
# 75153   55926 -3.960480 -1.206079 -0.504628  ...  0.413672  0.517313   18.00    0.0
# 84793   60463 -1.127453  0.977291  2.045295  ...  0.250898 -0.051669   37.76    0.0
# 82209   59299  1.320679 -0.978623 -0.811041  ... -0.000535  0.002267   99.84    0.0
# 63625   50805  0.897496 -0.885714  1.070778  ... -0.049378  0.019508  118.63    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#          Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 106998  70229  0.315642  1.636778 -1.519650  ...  0.589595  0.309064    3.79    1.0
# 107067  70270 -1.512516  1.133139 -1.601052  ...  0.414482  0.267265  318.11    1.0
# 107637  70536 -2.271755 -0.457655 -2.589055  ...  0.258194  0.247269  824.83    1.0
# 108258  70828  0.196707  1.189757  0.704882  ...  0.135215  0.257315    0.76    1.0
# 108708  71033 -3.170818  0.185735 -3.399852  ...  0.859282  0.225924  426.40    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    239
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2  ...       V27       V28      Amount
# Class                                    ...
# 0.0    44599.963415 -0.259599 -0.119274  ... -0.022045  0.016658   96.915833
# 1.0    38848.740586 -5.982672  4.179679  ...  0.533488  0.067655  119.677573
#
# [2 rows x 30 columns]

# %%
x = new_dataset.drop(columns='Class', axis=1)
y = new_dataset['Class']

# %%
print(x)
# Out:
#          Time        V1        V2  ...       V27       V28  Amount
# 107187  70322 -0.830736 -0.099328  ...  0.018876  0.124941  106.04
# 75153   55926 -3.960480 -1.206079  ...  0.413672  0.517313   18.00
# 84793   60463 -1.127453  0.977291  ...  0.250898 -0.051669   37.76
# 82209   59299  1.320679 -0.978623  ... -0.000535  0.002267   99.84
# 63625   50805  0.897496 -0.885714  ... -0.049378  0.019508  118.63
# ...       ...       ...       ...  ...       ...       ...     ...
# 106998  70229  0.315642  1.636778  ...  0.589595  0.309064    3.79
# 107067  70270 -1.512516  1.133139  ...  0.414482  0.267265  318.11
# 107637  70536 -2.271755 -0.457655  ...  0.258194  0.247269  824.83
# 108258  70828  0.196707  1.189757  ...  0.135215  0.257315    0.76
# 108708  71033 -3.170818  0.185735  ...  0.859282  0.225924  426.40
#
# [731 rows x 30 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=2)

# %%
print(x.shape,x_train.shape, x_test.shape)
# Out:
# (731, 30) (584, 30) (147, 30)

# %%
model=LogisticRegression()

# %%
X = creditcard_data.drop(columns=['Class'])
y = creditcard_data['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2, stratify=y
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3303600700.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(
#       4     X, y, test_size=0.2, random_state=2, stratify=y
#       5 )
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2870         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2871
# -> 2872         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2873
#    2874     train, test = ensure_common_namespace_device(arrays[0], train, test)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    2403                 UserWarning,
#    2404             )
# -> 2405         y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#    2406         return super().split(X, y, groups)
#    2407
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1105
#    1106         if ensure_all_finite:
# -> 1107             _assert_all_finite(
#    1108                 array,
#    1109                 input_name=input_name,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     118         return
#     119
# --> 120     _assert_all_finite_element_wise(
#     121         X,
#     122         xp=xp,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     167                 "#estimators-that-handle-nan-values"
#     168             )
# --> 169         raise ValueError(msg_err)
#     170
#     171
#
# ValueError: Input y contains NaN.

# %%
y.isnull().sum()
# Out:
# np.int64(1)

# %%
data = creditcard_data.dropna(subset=['Class'])  # replace 'Class' with your target column name
X = data.drop(columns=['Class'])
y = data['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2, stratify=y
)

# %%
print(X.isnull().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# Scale data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train model
model = LogisticRegression(max_iter=1000)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model = LogisticRegression(solver='liblinear', max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3914317707.py in <cell line: 0>()
#       1 x_train_prediction = model.predict(x_train)
# ----> 2 training_data_accuracy = accuracy_score(x_train_prediction, y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     225     # Compute accuracy for each possible representation
#     226     y_true, y_pred = attach_unique(y_true, y_pred)
# --> 227     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     228     check_consistent_length(y_true, y_pred, sample_weight)
#     229
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      96     """
#      97     xp, _ = get_namespace(y_true, y_pred)
# ---> 98     check_consistent_length(y_true, y_pred)
#      99     type_true = type_of_target(y_true, input_name="y_true")
#     100     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     473     uniques = np.unique(lengths)
#     474     if len(uniques) > 1:
# --> 475         raise ValueError(
#     476             "Found input variables with inconsistent numbers of samples: %r"
#     477             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [584, 88802]

# %%
# Correct evaluation on training data
y_train_pred = model.predict(X_train)
training_data_accuracy = accuracy_score(y_train, y_train_pred)

print(" Accuracy on Training Data:", training_data_accuracy)
# Out:
#  Accuracy on Training Data: 0.998761289160154

# %%
y_test_pred = model.predict(X_test)
test_data_accuracy = accuracy_score(y_test, y_test_pred)

print(" Accuracy on Test Data:", test_data_accuracy)
# Out:
#  Accuracy on Test Data: 0.9986487095175893

# %%
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3212477515.py in <cell line: 0>()
# ----> 1 x_test_prediction = model.predict(x_test)
#       2 test_data_accuracy = accuracy_score(x_test_prediction, y_test)
#
# NameError: name 'model' is not defined

# %%
# 1️⃣ Import required libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# 2️⃣ Prepare X (features) and y (target)
# 👉 Replace 'Class' with your correct column name if different
X = creditcard_data.drop(columns=['Class'])
y = creditcard_data['Class']

# 3️⃣ Drop rows with missing target values
import numpy as np
valid_rows = ~y.isna()
X = X[valid_rows]
y = y[valid_rows]

# 4️⃣ Split data into train and test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2, stratify=y
)

# 5️⃣ Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 6️⃣ Train Logistic Regression model
model = LogisticRegression(max_iter=2000)
model.fit(X_train_scaled, y_train)

# 7️⃣ Evaluate model
y_train_pred = model.predict(X_train_scaled)
y_test_pred = model.predict(X_test_scaled)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

print(" Training Accuracy:", train_acc)
print(" Test Accuracy:", test_acc)

# 8️⃣ (Optional) More details
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
print("\nClassification Report:\n", classification_report(y_test, y_test_pred))
# Out:
#  Training Accuracy: 0.9990145135280416
#  Test Accuracy: 0.9989251164457184
#
# Confusion Matrix:
#  [[2779    1]
#  [   2    9]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2780
#          1.0       0.90      0.82      0.86        11
#
#     accuracy                           1.00      2791
#    macro avg       0.95      0.91      0.93      2791
# weighted avg       1.00      1.00      1.00      2791

# %%
import pandas as pd

# Replace 'creditcard.csv' with the path to your dataset
creditcard_data = pd.read_csv('creditcard.csv')

# Quick check
print(creditcard_data.head())
print(creditcard_data.columns)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
